# %% [markdown]
# ## Volatility EWMA Estimators
#
# **Finding an estimate for the volatility after previously concluding that constant volatility is not a valid assumption.**

# %%
# Importing Data
import pandas as pd

df = pd.read_excel("C:/Users/Aksha/OneDrive/Documents/GitHub/systematic-alpha-research/01_data-cleaning/Signal_Project_Data_Cleaned.xlsx", sheet_name = "Data")
df.head()
# Out:
#         Date   EDOLLAR   SP500       US10  LEANHOG       JPY    GOLD   WHEAT  \
# 0 1984-03-23  71.84001  464.55 -33.070302    -5.24  0.012126  1145.9  857.50
# 1 1984-03-26  71.91001  464.65 -32.914052    -5.36  0.012139  1147.6  860.50
# 2 1984-03-27  71.89001  465.45 -32.976552    -4.79  0.012140  1146.4  859.75
# 3 1984-03-28  71.89001  467.70 -32.632802    -4.44  0.012153  1149.4  857.50
# 4 1984-03-29  71.86001  466.40 -32.445302    -4.56  0.012147  1148.9  858.25
#
#    NIKKEI  COPPER  BITCOIN
# 0     NaN     NaN      NaN
# 1     NaN     NaN      NaN
# 2     NaN     NaN      NaN
# 3     NaN     NaN      NaN
# 4     NaN     NaN      NaN

# %% [markdown]
# ## Estimate 0 - Constant Volatility

# %%
futures_vol1 = df[1:].diff().std()
print(futures_vol1)

futures_vol2_results = []
for col in df.columns[1:]:
    s = df[col].dropna().diff()
    futures_vol2_results.append((col,s.std()))
    futures_vol2 = pd.DataFrame(futures_vol2_results)

print(futures_vol2)
# Out:
# Date       0 days 19:11:53.163543235
# EDOLLAR                       0.0742
# SP500                      18.532178
# US10                        0.433431
# LEANHOG                     0.822816
# JPY                         0.000059
# GOLD                        9.956849
# WHEAT                       8.752059
# NIKKEI                    232.032758
# COPPER                      0.042538
# BITCOIN                   1155.88755
# dtype: object
#          0            1
# 0  EDOLLAR     0.074199
# 1    SP500    18.531262
# 2     US10     0.433412
# 3  LEANHOG     0.822776
# 4      JPY     0.000059
# 5     GOLD     9.956370
# 6    WHEAT     8.751677
# 7   NIKKEI   286.468982
# 8   COPPER     0.042538
# 9  BITCOIN  1155.887550

# %% [markdown]
# ## Estimate 1 - Exponential Weighting

# %%
futures_diff = df.diff()
print(futures_diff)

vol_dict = {}
for col in df.columns[1:]:
    s = df[col].dropna().diff().dropna()
    vol_dict[col] = s.ewm(span=32).std().dropna()

exp_results = pd.DataFrame(vol_dict)  
print(exp_results)
# Out:
#         Date  EDOLLAR  SP500      US10  LEANHOG           JPY  GOLD  WHEAT  \
# 0        NaT      NaN    NaN       NaN      NaN           NaN   NaN    NaN
# 1     3 days    0.070   0.10  0.156250   -0.120  1.300000e-05   1.7   3.00
# 2     1 days   -0.020   0.80 -0.062500    0.570  1.000000e-06  -1.2  -0.75
# 3     1 days    0.000   2.25  0.343750    0.350  1.300000e-05   3.0  -2.25
# 4     1 days   -0.030  -1.30  0.187500   -0.120 -6.000000e-06  -0.5   0.75
# ...      ...      ...    ...       ...      ...           ...   ...    ...
# 10111 3 days    0.000   0.00  0.000000    0.000  0.000000e+00   0.0   0.00
# 10112 1 days   -0.085 -12.25 -0.718750    1.075 -3.700000e-05  15.8  -2.00
# 10113 1 days   -0.075 -45.75 -0.296875    0.125 -5.100000e-05  -9.8  11.75
# 10114 1 days    0.045  59.00  0.000000   -0.875  7.700000e-05   9.9   0.00
# 10115 1 days   -0.065   0.00  0.000000   -0.175  6.200000e-05   0.4   0.00
#
#        NIKKEI  COPPER  BITCOIN
# 0         NaN     NaN      NaN
# 1         NaN     NaN      NaN
# 2         NaN     NaN      NaN
# 3         NaN     NaN      NaN
# 4         NaN     NaN      NaN
# ...       ...     ...      ...
# 10111     0.0  0.0000      0.0
# 10112   280.0  0.0380   -215.0
# 10113  -310.0 -0.0175    -40.0
# 10114     0.0 -0.0045    -10.0
# 10115     0.0 -0.0225     95.0
#
# [10116 rows x 11 columns]
#         EDOLLAR      SP500      US10   LEANHOG       JPY       GOLD  \
# 2      0.063640   0.494975  0.154680  0.487904  0.000008   2.050610
# 3      0.046401   1.103888  0.206342  0.346105  0.000007   2.172995
# 4      0.043971   1.519936  0.166927  0.345028  0.000010   1.952416
# 5      0.064741   1.298165  0.366830  0.493715  0.000009   2.216700
# 6      0.058189   1.302992  0.323010  0.790511  0.000010   4.216449
# ...         ...        ...       ...       ...       ...        ...
# 10111  0.082090  54.345756  0.506819  1.642389  0.000092  18.078640
# 10112  0.081950  52.704857  0.519286  1.608411  0.000090  17.866585
# 10113  0.081027  52.021429  0.506402  1.558973  0.000089  17.562306
# 10114  0.079779  52.944497  0.491201  1.532452  0.000088  17.141986
# 10115  0.078489  51.322428  0.476433  1.486955  0.000086  16.619215
#
#            WHEAT      NIKKEI    COPPER     BITCOIN
# 2       2.651650         NaN       NaN         NaN
# 3       2.680538         NaN       NaN         NaN
# 4       2.198842         NaN       NaN         NaN
# 5       3.823552         NaN       NaN         NaN
# 6       3.501041         NaN       NaN         NaN
# ...          ...         ...       ...         ...
# 10111  10.886444  294.374343  0.055710  515.088983
# 10112  10.558123  298.074245  0.054612  501.352404
# 10113  10.658068  295.474515  0.053245  485.923128
# 10114  10.330168  286.880600  0.051656  471.013172
# 10115  10.012349  278.505668  0.050486  457.607881
#
# [10114 rows x 10 columns]

# %%
import matplotlib.pyplot as plt
import numpy as np

for col in exp_results:
    plt.figure(figsize=(12,5))
    plt.plot(exp_results[col], linewidth = 0.8, color = "steelblue", label = f"{col}")
    plt.title(f"{col} exponentially weighted volatility over 10000 trading days")
    plt.ylabel("Volatility")
    plt.xlabel("Trading Days")
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Estimate 2 - Exponential Weighting with Fast/Slow Averages

# %%
def compute_ewma_vol(price_series, fast_span=32, slow_window=2560, blend_fast=0.7, blend_slow=0.3, min_obs=60):
    diffs = price_series.diff()

    # Fast Component
    fast_vol = diffs.ewm(span=fast_span, min_periods=min_obs).std()
    
    # Slow component
    slow_vol = diffs.ewm(span=slow_window, min_periods=min_obs).std()
    
    blended_vol = blend_fast * fast_vol + blend_slow * slow_vol

    return blended_vol

vol_dict2 = {}
for col in df.columns[1:]:
    s = df[col].dropna().diff().dropna()
    vol_dict2[col] = compute_ewma_vol(s).dropna()

exp_results2 = pd.DataFrame(vol_dict2)  
print(exp_results2)
# Out:
#         EDOLLAR      SP500      US10   LEANHOG       JPY       GOLD  \
# 1           NaN        NaN       NaN       NaN       NaN        NaN
# 2           NaN        NaN       NaN       NaN       NaN        NaN
# 3           NaN        NaN       NaN       NaN       NaN        NaN
# 4           NaN        NaN       NaN       NaN       NaN        NaN
# 5           NaN        NaN       NaN       NaN       NaN        NaN
# ...         ...        ...       ...       ...       ...        ...
# 10111  0.098796  70.348321  0.661655  2.200425  0.000123  26.225469
# 10112  0.098024  68.701133  0.662956  2.159794  0.000120  25.813932
# 10113  0.095843  67.368555  0.654887  2.119211  0.000117  25.762672
# 10114  0.096899  68.991823  0.643443  2.079909  0.000117  25.497370
# 10115  0.097373  68.446197  0.629283  2.038075  0.000114  24.995246
#
#            WHEAT      NIKKEI    COPPER      BITCOIN
# 1            NaN         NaN       NaN          NaN
# 2            NaN         NaN       NaN          NaN
# 3            NaN         NaN       NaN          NaN
# 4            NaN         NaN       NaN          NaN
# 5            NaN         NaN       NaN          NaN
# ...          ...         ...       ...          ...
# 10111  16.131631  437.318942  0.079999  1022.301813
# 10112  15.801314  432.048772  0.078554  1008.013987
# 10113  15.743822  441.866150  0.077637   993.824221
# 10114  15.639876  437.889071  0.075948   979.023872
# 10115  15.318913  428.772349  0.074338   964.989099
#
# [10115 rows x 10 columns]

# %%
for col in exp_results2:
    plt.figure(figsize=(12,5))
    plt.plot(exp_results2[col], linewidth = 0.8, color = "steelblue", label = f"{col}")
    plt.title(f"{col} exponentially weighted volatility over 10000 trading days")
    plt.ylabel("Volatility")
    plt.xlabel("Trading Days")
    plt.tight_layout()
    plt.show()
